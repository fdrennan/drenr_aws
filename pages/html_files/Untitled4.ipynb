# %%
import requests

# %%
page = requests.get('https://www.spc.noaa.gov/products/md/md0808.html')

# %%
page
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser')

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN">
#
# <html>
# <head>
# <title>Storm Prediction Center Mesoscale Discussion 808</title>
# <meta content="Storm Prediction Center Forecast Products Page" name="DC.title"/>
# <meta content="SPC Forecast Products Page" name="DC.description"/>
# <meta content="Storm Prediction Center forecast products: tornado/severe thunderstorm watches, mesoscale discussions, day 1, 2, 3 convective outlooks, fire weather day 1, 2 outlooks" name="DC.subject"/>
# <meta content="2018-06-21" name="DC.date.reviewed" scheme="ISO8601"/>
# <meta content="2001-01-01" name="DC.date.created" scheme="ISO8601"/>
# <meta content="text/html; charset=iso-8859-1" name="DC.format"/>
# <meta content="EN-US" name="DC.language" scheme="DCTERMS.RFC1766"/>
# <meta content="Global" name="DC.Distribution"/>
# <meta content="all" name="DC.robot"/>
# <meta content="Storm Prediction Center" name="DC.creator"/>
# ...
